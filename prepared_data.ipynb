# %%
import sys
import os
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from functools import reduce

# %%
print(os.getcwd())
# Out:
# /Users/maryammoradi/Documents/Documents/uni/Thesis/bc_thesis

# %% [markdown]
# # create base_directory

# %%
# loead data from csv files
base_dir = "/Users/maryammoradi/Documents/Documents/uni/Thesis/bc_thesis"

# %%
def load_csv(filename):
    path = os.path.join(base_dir, filename)
    if not os.path.exists(path):
        raise FileNotFoundError(f"File not found: {filename}")
    
    encodings = ["utf-8", "latin1"]
    skip_options = [0, 4] 

    for skip in skip_options:
        for enc in encodings:
            try:
                df = pd.read_csv(path, encoding=enc, skiprows=skip)
                if df.shape[1] > 5: 
                    print(f"✅ Loaded: {filename:<45} | Enc: {enc:<6} | Skip: {skip} | Shape: {df.shape}")
                    return df
            except Exception:
                continue 
    print(f" file failed to load: {filename}")
    return None

# %% [markdown]
# # Load all datasets

# %%
df_gdp = load_csv("gdp_pc_ppp_const2021.csv")
df_bmi = load_csv("High_BMI.CSV")
df_incident = load_csv("incident.csv")
df_internet = load_csv("Internet users (% of population).csv")
df_mortality = load_csv("mortality.csv")         
df_population65 = load_csv("Population_ages_65(%od total).csv") 
df_urban = load_csv("Urben_population(% of total population).csv") 
df_Smoking = load_csv("smoking_female.csv")
df_health = load_csv("Current_health_expenditure.csv")
df_broadband = load_csv("Fixed_broadband_subscriptions (per 100 people).csv")
df_fertility = load_csv("Fertility rate, total (births per woman).csv")
df_life_expectency = load_csv("Life_expectancy_at_birth_female_(years).csv")
df_gov_spending = load_csv("government_health_spending.csv")
df_female_labor = load_csv("female_labor_participation.csv")
print(" all files are correctly loaded :)")
# Out:
# ✅ Loaded: gdp_pc_ppp_const2021.csv                      | Enc: utf-8  | Skip: 0 | Shape: (271, 69)
# ✅ Loaded: High_BMI.CSV                                  | Enc: utf-8  | Skip: 0 | Shape: (1654848, 12)
# ✅ Loaded: incident.csv                                  | Enc: utf-8  | Skip: 0 | Shape: (6936, 18)
# ✅ Loaded: Internet users (% of population).csv          | Enc: utf-8  | Skip: 0 | Shape: (271, 69)
# ✅ Loaded: mortality.csv                                 | Enc: utf-8  | Skip: 0 | Shape: (8976, 16)
# ✅ Loaded: Population_ages_65(%od total).csv             | Enc: utf-8  | Skip: 0 | Shape: (271, 69)
# ✅ Loaded: Urben_population(% of total population).csv   | Enc: utf-8  | Skip: 0 | Shape: (271, 69)
# ✅ Loaded: smoking_female.csv                            | Enc: utf-8  | Skip: 0 | Shape: (537, 69)
# ✅ Loaded: Current_health_expenditure.csv                | Enc: utf-8  | Skip: 0 | Shape: (271, 69)
# ...

# %%
#checking and printing the shapes of the data frames
print([df_gdp.shape,
       df_bmi.shape,
       df_incident.shape,
       df_internet.shape,
       df_mortality.shape,
       df_population65.shape,
       df_urban.shape,
       df_Smoking.shape,
       df_health.shape,
       df_broadband.shape,
       df_fertility.shape,
       df_life_expectency.shape])
# Out:
# [(271, 69), (1654848, 12), (6936, 18), (271, 69), (8976, 16), (271, 69), (271, 69), (537, 69), (271, 69), (271, 69), (271, 69), (271, 69)]

# %%
# The file of gdb needs latin1 encoding.
df_gdp=load_csv("gdp_pc_ppp_const2021.csv")
#df_gdb = load_csv("GDB.csv", encoding="latin1")
print("All files loaded successfully.")
# Out:
# ✅ Loaded: gdp_pc_ppp_const2021.csv                      | Enc: utf-8  | Skip: 0 | Shape: (271, 69)
# All files loaded successfully.

# %% [markdown]
# # GDP

# %%
df_gdp=pd.read_csv(os.path.join(base_dir, "gdp_pc_ppp_const2021.csv"))
print("df_gdp:")
print(df_gdp.head())
#print(df_gdp.columns.tolist())
# Out:
# df_gdp:
#                                          Series Name        Series Code  \
# 0  GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
# 1  GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
# 2  GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
# 3  GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
# 4  GDP per capita, PPP (constant 2021 internation...  NY.GDP.PCAP.PP.KD
#
#      Country Name Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962]  \
# 0     Afghanistan          AFG            ..            ..            ..
# 1         Albania          ALB            ..            ..            ..
# 2         Algeria          DZA            ..            ..            ..
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  ...     2015 [YR2015]  \
# ...

# %% [markdown]
# # Editing and cleaning Dataframe:

# %%
df_gdp_melted = df_gdp.melt(id_vars=['Country Name', 'Country Code', 'Series Name', 'Series Code'],
                           var_name='year_raw', value_name='gdp_value')
df_gdp_finally = df_gdp_melted[['Country Name', 'year_raw', 'gdp_value']].copy()
df_gdp_finally.columns = ['country', 'year', 'gdp']
df_gdp_finally['year'] = df_gdp_finally['year'].astype(str).str[:4]
df_gdp_finally['country'] = df_gdp_finally['country'].str.strip().str.lower()
df_gdp_finally['gdp'] = pd.to_numeric(df_gdp_finally['gdp'], errors='coerce')
df_gdp_finally['year'] = pd.to_numeric(df_gdp_finally['year'], errors='coerce')
df_gdp_finally = df_gdp_finally.dropna(subset=['gdp', 'year'])
#df_gdp_finally['year'] = df_gdp_finally['year'].astype(int)

print(df_gdp_finally.head(6))
# Out:
#                   country  year           gdp
# 8131              albania  1990   5560.857871
# 8132              algeria  1990  11728.545729
# 8134              andorra  1990  50036.300776
# 8135               angola  1990   7391.752354
# 8136  antigua and barbuda  1990  21074.576436
# 8137            argentina  1990  17007.284432

# %%
missing_percentage = df_gdp_finally['gdp'].isnull().sum() / len(df_gdp_finally) * 100
print(f" percent of NaN in gdp column: {missing_percentage:.2f}%")
# Out:
#  percent of NaN in gdp column: 0.00%

# %% [markdown]
# # ‌BMI Data :

# %%
df_bmi = pd.read_csv(os.path.join(base_dir, "High_BMI.csv"))
print("df_bmi:")
print(df_bmi.head())
# Out:
# df_bmi:
#    age_group_id age_group_name  sex_id   sex  year_id  location_id  \
# 0             6         5 to 9       3  Both     1990            6
# 1             6         5 to 9       3  Both     1991            6
# 2             6         5 to 9       3  Both     1992            6
# 3             6         5 to 9       3  Both     1993            6
# 4             6         5 to 9       3  Both     1994            6
#
#   location_name     measure  \
# 0         China  proportion
# 1         China  proportion
# 2         China  proportion
# 3         China  proportion
# 4         China  proportion
#
#                                           definition      mean     lower  \
# 0  Prevalence overweight, excluding obese (25>=BM...  0.093850  0.068234
# 1  Prevalence overweight, excluding obese (25>=BM...  0.096039  0.070187
# 2  Prevalence overweight, excluding obese (25>=BM...  0.098245  0.071657
# 3  Prevalence overweight, excluding obese (25>=BM...  0.100470  0.073484
# ...

# %% [markdown]
# Firstly we need to filter data base on specific period of age and relevant sex because breast cancer risk straight linked to to BMI women.
# Typically sex_id = 2 related to Females

# %%
df_bmi_filtered = df_bmi[(df_bmi['sex'] == 'Female') | (df_bmi['sex_id'] == 2)].copy()
df_bmi_finally = df_bmi_filtered[['location_name', 'year_id', 'mean']].copy()
df_bmi_finally.columns = ['country', 'year', 'bmi_female']
df_bmi_finally['country'] = df_bmi_finally['country'].astype(str).str.strip().str.lower()
df_bmi_finally['year'] = pd.to_numeric(df_bmi_finally['year'], errors='coerce').astype(int)
df_bmi_finally['bmi_female'] = pd.to_numeric(df_bmi_finally['bmi_female'], errors='coerce')
print(df_bmi_finally.head(5))
# Out:
#    country  year  bmi_female
# 35   china  1990    0.100224
# 37   china  1991    0.103344
# 39   china  1992    0.106495
# 41   china  1993    0.109678
# 43   china  1994    0.112884

# %%
df_gdp_melted = df_gdp.melt(id_vars=['Country Name', 'Country Code', 'Series Name', 'Series Code'],
                           var_name='year_raw', value_name='gdp_value')
df_gdp_finally = df_gdp_melted[['Country Name', 'year_raw', 'gdp_value']].copy()
df_gdp_finally.columns = ['country', 'year_raw', 'gdp']
df_gdp_finally['year'] = df_gdp_finally['year_raw'].astype(str).str[:4]
#df_gdp_finally['year'] = pd.to_numeric(df_gdp_finally['year'], errors='coerce')
df_gdp_finally['country'] = df_gdp_finally['country'].astype(str).str.strip().str.lower()
df_gdp_finally['gdp'] = pd.to_numeric(df_gdp_finally['gdp'], errors='coerce')
df_gdp_finally = df_gdp_finally[['country', 'year', 'gdp']].copy()
df_gdp_finally = df_gdp_finally.dropna(subset=['gdp', 'year'])
df_gdp_finally['year'] = df_gdp_finally['year'].astype(int)

print(df_gdp_finally.head(6))
# Out:
#                   country  year           gdp
# 8131              albania  1990   5560.857871
# 8132              algeria  1990  11728.545729
# 8134              andorra  1990  50036.300776
# 8135               angola  1990   7391.752354
# 8136  antigua and barbuda  1990  21074.576436
# 8137            argentina  1990  17007.284432

# %%
missing_percentage = df_bmi_finally['bmi_female'].isnull().sum() / len(df_bmi_finally) * 100
print(f" percent of NaN in bmi_female column: {missing_percentage:.2f}%")
# Out:
#  percent of NaN in bmi_female column: 0.00%

# %% [markdown]
# # Broadband (powerfull internet) data:

# %%
df_broadband = pd.read_csv(os.path.join(base_dir, "Fixed_broadband_subscriptions (per 100 people).csv"))
print("df_broadbank:")
print(df_broadband.head())
# Out:
# df_broadbank:
#                                       Series Name     Series Code  \
# 0  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 1  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 2  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 3  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
# 4  Fixed broadband subscriptions (per 100 people)  IT.NET.BBND.P2
#
#      Country Name Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962]  \
# 0     Afghanistan          AFG            ..            ..            ..
# 1         Albania          ALB            ..            ..            ..
# 2         Algeria          DZA            ..            ..            ..
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  ... 2015 [YR2015] 2016 [YR2016]  \
# ...

# %%
df_broadband_melted = df_broadband.melt(
    id_vars=['Country Name', 'Country Code'], 
    var_name='year_raw', value_name='broadband_value')

# %%
df_broadband_finally = df_broadband_melted[['Country Name', 'year_raw', 'broadband_value']].copy()
df_broadband_finally.columns = ['country', 'year', 'broadband']
# cleaning Year column to extract just the year part:
df_broadband_finally['year'] = df_broadband_finally['year'].astype(str).str[:4]   # making country name and year consistent with other dataframes:
df_broadband_finally['country'] = df_broadband_finally['country'].astype(str).str.strip().str.lower()
df_broadband_finally['year'] = df_broadband_finally['year'].astype(str).str.strip()
#changing data type to numeric
df_broadband_finally['broadband'] = pd.to_numeric(df_broadband_finally['broadband'], errors='coerce')
df_broadband_finally = df_broadband_finally[df_broadband_finally['year'].str.isnumeric()]
df_broadband_finally = df_broadband_finally.dropna(subset=['country'])
df_broadband_finally = df_broadband_finally[df_broadband_finally['country'] != 'nan']
print(df_broadband_finally.head(30))
# Out:
#                     country  year  broadband
# 542             afghanistan  1960        NaN
# 543                 albania  1960        NaN
# 544                 algeria  1960        NaN
# 545          american samoa  1960        NaN
# 546                 andorra  1960        NaN
# 547                  angola  1960        NaN
# 548     antigua and barbuda  1960        NaN
# 549               argentina  1960        NaN
# 550                 armenia  1960        NaN
# 551                   aruba  1960        NaN
# 552               australia  1960        NaN
# 553                 austria  1960        NaN
# 554              azerbaijan  1960        NaN
# 555            bahamas, the  1960        NaN
# 556                 bahrain  1960        NaN
# 557              bangladesh  1960        NaN
# 558                barbados  1960        NaN
# 559                 belarus  1960        NaN
# 560                 belgium  1960        NaN
# 561                  belize  1960        NaN
# ...

# %%
missing_percentage = df_broadband_finally['broadband'].isnull().sum() / len(df_broadband_finally) * 100
print(f" percent of NaN in Broadband column: {missing_percentage:.2f}%")
# Out:
#  percent of NaN in Broadband column: 70.45%

# %% [markdown]
# # Health Expenditure

# %%
df_health = pd.read_csv(os.path.join(base_dir, "Current_health_expenditure.csv"))
print("df_health:")
print(df_health.head())
# Out:
# df_health:
#                              Series Name        Series Code    Country Name  \
# 0  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS     Afghanistan
# 1  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS         Albania
# 2  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS         Algeria
# 3  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS  American Samoa
# 4  Current health expenditure (% of GDP)  SH.XPD.CHEX.GD.ZS         Andorra
#
#   Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# 0          AFG            ..            ..            ..            ..
# 1          ALB            ..            ..            ..            ..
# 2          DZA            ..            ..            ..            ..
# 3          ASM            ..            ..            ..            ..
# 4          AND            ..            ..            ..            ..
#
# ...

# %% [markdown]
# Changing wide to long with Melt funtion

# %%
df_health_melted = df_health.melt(
    id_vars=['Country Name', 'Country Code'], 
    var_name='year_raw', 
    value_name='health_exp_value')
df_health_finally = df_health_melted[['Country Name', 'year_raw', 'health_exp_value']].copy()
df_health_finally.columns = ['country', 'year', 'health_exp']
df_health_finally['year'] = df_health_finally['year'].astype(str).str[:4]

# all countries to be consistent formatting.
df_health_finally['country'] = df_health_finally['country'].astype(str).str.strip().str.lower()

# changing data type to numeric
df_health_finally['health_exp'] = pd.to_numeric(df_health_finally['health_exp'], errors='coerce')

# deleting rows with non-numeric years and NAN countries,
df_health_finally = df_health_finally[df_health_finally['year'].str.isnumeric()]
df_health_finally = df_health_finally.dropna(subset=['country'])
df_health_finally = df_health_finally[df_health_finally['country'] != 'nan']

# %%
print("Checking year 2020 for Health Data:")
print(df_health_finally[df_health_finally['year'] == '2020'].head(10))
# Out:
# Checking year 2020 for Health Data:
#                    country  year  health_exp
# 16802          afghanistan  2020   15.533614
# 16803              albania  2020    7.503894
# 16804              algeria  2020    5.638317
# 16805       american samoa  2020         NaN
# 16806              andorra  2020    8.786739
# 16807               angola  2020    3.274885
# 16808  antigua and barbuda  2020    5.729448
# 16809            argentina  2020   10.450306
# 16810              armenia  2020   12.240562
# 16811                aruba  2020         NaN

# %% [markdown]
# Cleaning Year_raw and changing string to Num

# %%
missing_percentage = df_health_finally['health_exp'].isnull().sum() / len(df_health_finally) * 100
print(f"Percent of NaN in health expenditure column: {missing_percentage:.2f}%")
# Out:
# Percent of NaN in health expenditure column: 68.40%

# %% [markdown]
# # INCIDENT:

# %%
df_incident = pd.read_csv(os.path.join(base_dir, "incident.csv"))
print("df_incident")
print(df_incident.head())
# Out:
# df_incident
#    population_group_id population_group_name  measure_id measure_name  \
# 0                    1        All Population           6    Incidence
# 1                    1        All Population           6    Incidence
# 2                    1        All Population           6    Incidence
# 3                    1        All Population           6    Incidence
# 4                    1        All Population           6    Incidence
#
#    location_id location_name  sex_id sex_name  age_id  age_name  cause_id  \
# 0          204          Chad       2   Female      22  All ages       429
# 1          163         India       2   Female      22  All ages       429
# 2          385   Puerto Rico       2   Female      22  All ages       429
# 3          150          Oman       2   Female      22  All ages       429
# 4          191        Zambia       2   Female      22  All ages       429
#
#       cause_name  metric_id metric_name  year        val      upper      lower
# ...

# %%
df_incident_finally= df_incident[['location_name', 'year', 'val']].copy()
df_incident_finally.columns = ['country', 'year', 'incidence_rate']
df_incident_finally['country'] = df_incident_finally['country'].astype(str).str.strip().str.lower()
df_incident_finally['year']= df_incident_finally['year'].astype(str).str.strip()
print(df_incident_finally.head(10))
# Out:
#        country  year  incidence_rate
# 0         chad  1990       11.784239
# 1        india  1990        8.650421
# 2  puerto rico  1990       51.408888
# 3         oman  1990        5.197615
# 4       zambia  1990       14.798816
# 5     djibouti  1990       15.847623
# 6     dominica  1990       38.448934
# 7      albania  1990       13.190594
# 8         peru  1990       13.623546
# 9        nepal  1990        5.590792

# %%
missing_percentage = df_incident_finally['incidence_rate'].isnull().sum() / len(df_incident_finally) * 100
print(f" percent of NaN in incidence_rate column: {missing_percentage:.2f}%")
# Out:
#  percent of NaN in incidence_rate column: 0.00%

# %% [markdown]
# # INTERNET USAGE:

# %%
df_internet = pd.read_csv(os.path.join(base_dir, "internet users (% of population).csv"))
print("df_internet:")
print(df_internet.head())
# Out:
# df_internet:
#                                         Series Name     Series Code  \
# 0  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 1  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 2  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 3  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 4  Individuals using the Internet (% of population)  IT.NET.USER.ZS
#
#      Country Name Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962]  \
# 0     Afghanistan          AFG            ..            ..            ..
# 1         Albania          ALB            ..            ..            ..
# 2         Algeria          DZA            ..            ..            ..
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  ... 2015 [YR2015] 2016 [YR2016]  \
# ...

# %%
df_internet_melted = df_internet.melt(
    id_vars=['Country Name', 'Country Code'],  var_name='year_raw', 
    value_name='internet_usage_value')
df_internet_finally= df_internet_melted[['Country Name', 'year_raw', 'internet_usage_value']].copy()
df_internet_finally.columns = ['country', 'year', 'internet_users_pct']
# cleaning year column to extract part of year.
df_internet_finally['year']= df_internet_finally['year'].astype(str).str[:4]
#changing internet users percentage to numeric data type:
df_internet_finally['internet_users_pct']=df_internet_finally['internet_users_pct'].astype(str).str.strip()
df_internet_finally= df_internet_finally[df_internet_finally['year'].str.isnumeric()]
df_internet_finally= df_internet_finally[df_internet_finally['country'] !='nan']
df_internet_finally['internet_users_pct'] = pd.to_numeric(df_internet_finally['internet_users_pct'], errors='coerce')
# making country names for all dataframes have same format:
df_internet_finally['country'] = df_internet_finally['country'].astype(str).str.strip().str.lower()

print(df_internet_finally[df_internet_finally['year'] == '2008'].head())
# Out:
#               country  year  internet_users_pct
# 13550     afghanistan  2008                1.84
# 13551         albania  2008               23.86
# 13552         algeria  2008               10.18
# 13553  american samoa  2008                 NaN
# 13554         andorra  2008               70.04

# %%
missing_percentage = df_internet_finally['internet_users_pct'].isnull().sum() / len(df_internet_finally) * 100
print(f" percent of NaN in internet_users_pct column: {missing_percentage:.2f}%")
# Out:
#  percent of NaN in internet_users_pct column: 61.75%

# %% [markdown]
# # POPULATION 65 and above:

# %%
df_population65 = pd.read_csv(os.path.join(base_dir, "Population_ages_65(%od total).csv"))
print("df_population65:")
print(df_population65.head())
# Out:
# df_population65:
#                                          Series Name        Series Code  \
# 0  Population ages 65 and above (% of total popul...  SP.POP.65UP.TO.ZS
# 1  Population ages 65 and above (% of total popul...  SP.POP.65UP.TO.ZS
# 2  Population ages 65 and above (% of total popul...  SP.POP.65UP.TO.ZS
# 3  Population ages 65 and above (% of total popul...  SP.POP.65UP.TO.ZS
# 4  Population ages 65 and above (% of total popul...  SP.POP.65UP.TO.ZS
#
#      Country Name Country Code     1960 [YR1960]     1961 [YR1961]  \
# 0     Afghanistan          AFG  2.82336216754241  2.80935715469461
# 1         Albania          ALB  5.48661411785106  5.37214565303962
# 2         Algeria          DZA  3.12281781879999  3.24458921615304
# 3  American Samoa          ASM  2.63752638768161   2.5791778568145
# 4         Andorra          AND  6.99789695057834  6.51592511548748
#
#       1962 [YR1962]     1963 [YR1963]     1964 [YR1964]     1965 [YR1965]  \
# ...

# %%
#melting: 
df_pop65_melted = df_population65.melt(
    id_vars=['Series Name', 'Series Code', 'Country Name', 'Country Code'], 
    var_name='year_raw', 
    value_name='pop_value')

df_pop65_finally = df_pop65_melted[['Country Name', 'year_raw', 'pop_value']].copy()
# change columns names:
df_pop65_finally.columns = ['country', 'year', 'pop_65_pct']

df_pop65_finally['year'] = df_pop65_finally['year'].astype(str).str[:4]
df_pop65_finally['country'] = df_pop65_finally['country'].astype(str).str.strip().str.lower()
df_pop65_finally['pop_65_pct'] = pd.to_numeric(df_pop65_finally['pop_65_pct'], errors='coerce')
print(df_pop65_finally.head(5))
# Out:
#           country  year  pop_65_pct
# 0     afghanistan  1960    2.823362
# 1         albania  1960    5.486614
# 2         algeria  1960    3.122818
# 3  american samoa  1960    2.637526
# 4         andorra  1960    6.997897

# %% [markdown]
# Missing Pop_65_data:

# %%
missing_percentage = df_pop65_finally['pop_65_pct'].isnull().sum() / len(df_pop65_finally) * 100
print(f" percent of NaN in pop_65_pct column: {missing_percentage:.2f}%")
# Out:
#  percent of NaN in pop_65_pct column: 2.21%

# %% [markdown]
# # SMOKING:

# %%
df_smoking =pd.read_csv(os.path.join(base_dir, "smoking_female.csv"))
print("df_smoking:")
print(df_smoking.head())
#print(df_smoking.columns.tolist())
# Out:
# df_smoking:
#                                          Series Name     Series Code  \
# 0  Prevalence of current tobacco use, females (% ...  SH.PRV.SMOK.FE
# 1  Prevalence of current tobacco use, females (% ...  SH.PRV.SMOK.FE
# 2  Prevalence of current tobacco use, females (% ...  SH.PRV.SMOK.FE
# 3  Prevalence of current tobacco use, females (% ...  SH.PRV.SMOK.FE
# 4  Prevalence of current tobacco use, females (% ...  SH.PRV.SMOK.FE
#
#      Country Name Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962]  \
# 0     Afghanistan          AFG            ..            ..            ..
# 1         Albania          ALB            ..            ..            ..
# 2         Algeria          DZA            ..            ..            ..
# 3  American Samoa          ASM            ..            ..            ..
# 4         Andorra          AND            ..            ..            ..
#
#   1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  ... 2015 [YR2015] 2016 [YR2016]  \
# ...

# %%
df_smoking_melted= df_smoking.melt( 
                     id_vars=['Country Name', 'Country Code'],
                                   var_name='year_raw',
                                   value_name='smoking_prevalence')

# %%
year_cols = [c for c in df_smoking.columns if any(char.isdigit() for char in c)]
id_cols = [c for c in df_smoking.columns if c not in year_cols]
df_smoking_melted = df_smoking.melt(id_vars=id_cols, var_name='year_raw', value_name='smoking_prevalence')
df_smoking_finally = df_smoking_melted[['Country Name', 'year_raw', 'smoking_prevalence']].copy()
df_smoking_finally.columns = ['country', 'year', 'smoking_rate']
df_smoking_finally['year'] = df_smoking_finally['year'].astype(str).str[:4]
df_smoking_finally['country'] = df_smoking_finally['country'].astype(str).str.strip().str.lower()
df_smoking_finally['smoking_rate'] = pd.to_numeric(df_smoking_finally['smoking_rate'], errors='coerce')

print(df_smoking_finally.head(100))
# Out:
#            country  year  smoking_rate
# 0      afghanistan  1960           NaN
# 1          albania  1960           NaN
# 2          algeria  1960           NaN
# 3   american samoa  1960           NaN
# 4          andorra  1960           NaN
# ..             ...   ...           ...
# 95          israel  1960           NaN
# 96           italy  1960           NaN
# 97         jamaica  1960           NaN
# 98           japan  1960           NaN
# 99          jordan  1960           NaN
#
# [100 rows x 3 columns]

# %% [markdown]
# # calculating NA in smoking:

# %%
missing_percentage =df_smoking_finally['smoking_rate'].isnull().sum() / len(df_smoking_finally)*100
print(f"percentage of NaN in smoking_rate column:{missing_percentage: .2f}")
# Out:
# percentage of NaN in smoking_rate column: 86.39

# %% [markdown]
# # Life Expectency_Femail:

# %%
df_life_expectency=pd.read_csv(os.path.join(base_dir, "Life_expectancy_at_birth_female_(years).csv"))
print("df_life_expectency:")
print(df_life_expectency.head())
# Out:
# df_life_expectency:
#      Country Name Country Code                               Series Name  \
# 0     Afghanistan          AFG  Life expectancy at birth, female (years)
# 1         Albania          ALB  Life expectancy at birth, female (years)
# 2         Algeria          DZA  Life expectancy at birth, female (years)
# 3  American Samoa          ASM  Life expectancy at birth, female (years)
# 4         Andorra          AND  Life expectancy at birth, female (years)
#
#          Series Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# 0  SP.DYN.LE00.FE.IN        33.549        34.043        34.502        34.945
# 1  SP.DYN.LE00.FE.IN        58.877        59.995        61.047        62.086
# 2  SP.DYN.LE00.FE.IN        43.858         43.77        42.706        43.607
# 3  SP.DYN.LE00.FE.IN        67.107        67.916        68.427        68.567
# 4  SP.DYN.LE00.FE.IN        75.081        75.744        76.372        76.871
#
# ...

# %% [markdown]
# CLeaning

# %%
df_life_melted = df_life_expectency.melt(
    id_vars=['Series Name', 'Series Code', 'Country Name', 'Country Code'], 
    var_name='year_raw', 
    value_name='life_value')

# %%
df_life_expect_finally = df_life_melted[['Country Name', 'year_raw', 'life_value']].copy()
df_life_expect_finally.columns = ['country', 'year', 'life_expectancy']
df_life_expect_finally['year'] = df_life_expect_finally['year'].astype(str).str[:4]
df_life_expect_finally['country']= df_life_expect_finally['country'].astype(str).str.strip().str.lower()
df_life_expect_finally['life_expectancy'] = pd.to_numeric(df_life_expect_finally['life_expectancy'], errors='coerce')
print(df_life_expect_finally.head(5))
# Out:
#           country  year  life_expectancy
# 0     afghanistan  1960           33.549
# 1         albania  1960           58.877
# 2         algeria  1960           43.858
# 3  american samoa  1960           67.107
# 4         andorra  1960           75.081

# %%
missing_percentage= df_life_expect_finally['life_expectancy'].isnull().sum()/ len(df_life_expect_finally)*100
print(f'life_expectancy column NaN percentage: {missing_percentage: .2f}%')
# Out:
# life_expectancy column NaN percentage:  3.91%

# %% [markdown]
# # Fertility:

# %%
df_fertility=pd.read_csv(os.path.join(base_dir, "Fertility rate, total (births per woman).csv"))
print("df_fertility:")
print(df_fertility.head())
print(df_fertility.columns.tolist())
# Out:
# df_fertility:
#      Country Name Country Code                               Series Name  \
# 0     Afghanistan          AFG  Fertility rate, total (births per woman)
# 1         Albania          ALB  Fertility rate, total (births per woman)
# 2         Algeria          DZA  Fertility rate, total (births per woman)
# 3  American Samoa          ASM  Fertility rate, total (births per woman)
# 4         Andorra          AND  Fertility rate, total (births per woman)
#
#       Series Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# 0  SP.DYN.TFRT.IN         7.282         7.284         7.292         7.302
# 1  SP.DYN.TFRT.IN         6.383         6.273         6.106         5.927
# 2  SP.DYN.TFRT.IN         7.503         7.564         7.607         7.649
# 3  SP.DYN.TFRT.IN         6.578         6.575         6.603         6.687
# 4  SP.DYN.TFRT.IN         2.545         2.543         2.548         2.602
#
# ...

# %% [markdown]
# Cleaning:

# %%
df_fertility_melted= df_fertility.melt(id_vars= ['Country Name', 'Series Name','Country Code', 'Series Code'],
                                       var_name='year_raw', 
                                       value_name='fert_value')

# %%
df_fert_finally= df_fertility_melted[['Country Name', 'year_raw', 'fert_value']].copy()
df_fert_finally.columns= ['country', 'year', 'fertility_rate']
df_fert_finally['country']= df_fert_finally['country'].astype(str).str.strip().str.lower()
df_fert_finally['year']= df_fert_finally['year'].astype(str)
df_fert_finally['year']=df_fert_finally['year'].str[:4]
df_fert_finally['fertility_rate']= pd.to_numeric(df_fert_finally['fertility_rate'], errors='coerce')
df_fert_finally.head(4)
# Out:
#           country  year  fertility_rate
# 0     afghanistan  1960           7.282
# 1         albania  1960           6.383
# 2         algeria  1960           7.503
# 3  american samoa  1960           6.578

# %%
missing_percentage= df_fert_finally['fertility_rate'].isnull().sum()/ len(df_fert_finally)*100
print(f'fertility_rate column NaN percentage: {missing_percentage: .2f}%')
# Out:
# fertility_rate column NaN percentage:  3.90%

# %% [markdown]
# # Urben:

# %%
df_urban=pd.read_csv(os.path.join(base_dir, "Urben_population(% of total population).csv"))
print("df_urba:")
print(df_urban.head())
# Out:
# df_urba:
#      Country Name Country Code                               Series Name  \
# 0     Afghanistan          AFG  Urban population (% of total population)
# 1         Albania          ALB  Urban population (% of total population)
# 2         Algeria          DZA  Urban population (% of total population)
# 3  American Samoa          ASM  Urban population (% of total population)
# 4         Andorra          AND  Urban population (% of total population)
#
#          Series Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# 0  SP.URB.TOTL.IN.ZS         8.401         8.684         8.976         9.276
# 1  SP.URB.TOTL.IN.ZS        30.705        30.943        31.015        31.086
# 2  SP.URB.TOTL.IN.ZS         30.51        31.797        33.214        34.662
# 3  SP.URB.TOTL.IN.ZS        66.211        66.641        67.068        67.493
# 4  SP.URB.TOTL.IN.ZS         58.45        60.983        63.462        65.872
#
# ...

# %% [markdown]
# Cleaning:

# %%
df_urban_melted= df_urban.melt(id_vars=['Country Name', 'Country Code','Series Code','Series Name'],
                          var_name='year_raw', value_name='urban_pct')

# %%
df_urban_finally = df_urban_melted[['Country Name', 'year_raw', 'urban_pct']].copy()
df_urban_finally.columns = ['country', 'year', 'urban_rate']
df_urban_finally['country'] = df_urban_finally['country'].astype(str).str.strip().str.lower()
df_urban_finally['year'] = df_urban_finally['year'].astype(str).str.strip().str[:4]
df_urban_finally['urban_rate'] = pd.to_numeric(df_urban_finally['urban_rate'], errors='coerce')
df_urban_finally.head()
# Out:
#           country  year  urban_rate
# 0     afghanistan  1960       8.401
# 1         albania  1960      30.705
# 2         algeria  1960      30.510
# 3  american samoa  1960      66.211
# 4         andorra  1960      58.450

# %%
missing_percentage = df_urban_finally['urban_rate'].isnull().sum() / len(df_urban_finally) * 100
print(f'urban_rate column NaN percentage: {missing_percentage: .2f}%')
# Out:
# urban_rate column NaN percentage:  2.95%

# %% [markdown]
# Define Core Model:

# %%
dataframe_core ={'Incident Rate (Y)': df_incident_finally,
'GDP per capita': df_gdp_finally,
'BMI Female:' : df_bmi_finally,
'Population 65+': df_pop65_finally,
'Urban Population': df_urban_finally,
'Life Ex Fem' :df_life_expect_finally,
'Fertility Female': df_fert_finally}
core_report_data =[]
for var_name, df in dataframe_core.items():
    value_col=df.columns[-1]
    NaN_percent= (df[value_col].isnull().sum() /len(df))*100
    core_report_data.append([ var_name, f'{NaN_percent: 2f}%', "strong if NaN_Percentage is less %20 else 'weak'"])
df_core_report= pd.DataFrame(core_report_data, columns=['variable Name','Missing % of data','status'])

# %% [markdown]
# # Labor Femail:

# %%
df_female_labor =pd.read_csv(os.path.join(base_dir,"female_labor_participation.csv"), skiprows= 4)
print("df_female_labor:")
print(df_female_labor.head())
# Out:
# df_female_labor:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 1  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 2  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 3  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
# 4  Labor force participation rate, female (% of f...  SL.TLF.CACT.FE.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2016       2017       2018  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# ...

# %% [markdown]
# # Cleaning:

# %%
df_labor_long = df_female_labor.melt(
    id_vars=['Country Name', 'Country Code'], var_name='Year', 
    value_name='labor_rate')
df_labor_finally = pd.DataFrame()
df_labor_finally['country'] = df_labor_long['Country Name'].astype(str).str.strip().str.lower()
df_labor_finally['year'] = pd.to_numeric(df_labor_long['Year'], errors='coerce')
df_labor_finally['labor_rate'] = pd.to_numeric(df_labor_long['labor_rate'], errors='coerce')
# clean data and put year as integer:
df_labor_finally = df_labor_finally.dropna(subset=['year', 'labor_rate'])
df_labor_finally['year'] = df_labor_finally['year'].astype(int)

print(df_labor_finally.head(5))
# Out:
#                           country  year  labor_rate
# 8513  africa eastern and southern  1990   65.537699
# 8514                  afghanistan  1990   15.789000
# 8515   africa western and central  1990   69.940137
# 8516                       angola  1990   75.607000
# 8517                      albania  1990   50.846000

# %% [markdown]
# # Missing Data

# %%
missing_percentage = df_labor_finally['labor_rate'].isnull().sum() / len(df_labor_finally) * 100
print(f'labor_rate column NaN percentage: {missing_percentage: .2f}%')
# Out:
# labor_rate column NaN percentage:  0.00%

# %% [markdown]
# # Government Health Spending:

# %%
df_gov_spending = pd.read_csv(os.path.join(base_dir, "government_health_spending.csv"), skiprows=4)

# %% [markdown]
# Cleaning:

# %%
id_cols = ['Country Name', 'Country Code']
value_cols = [str(year) for year in range(1990, 2024)]

# %% [markdown]
# Deleting Extra Columns:

# %%
df_gov_droped = df_gov_spending.drop(columns=['Series Name', 'Series Code'], errors='ignore')

# %% [markdown]
# Filtering data:

# %%
columns_to_keep = id_cols + value_cols
df_gov_filtered = df_gov_droped[columns_to_keep].copy()

# %% [markdown]
# Melting table from horizontal to vertical:

# %%
df_gov_long = df_gov_filtered.melt(id_vars=id_cols, 
                     var_name='Year', value_name='Gov_Health_Spending')
df_gov_final = df_gov_long.copy()
df_gov_final['Gov_Health_Spending'] = pd.to_numeric(df_gov_final['Gov_Health_Spending'], errors='coerce')
df_gov_final['Year'] = df_gov_final['Year'].astype(float)

# %% [markdown]
# Report for missing data or NA

# %%
missing_percentage_gov = df_gov_final['Gov_Health_Spending'].isnull().sum() / len(df_gov_final) * 100
print(f'Gov_Health_Spending column NaN percentage: {missing_percentage_gov: .2f}%')
# Out:
# Gov_Health_Spending column NaN percentage:  47.30%

# %%
# Report_dropped_variables

# %% [markdown]
# # Main_Report

# %%
def get_nan_pct(df):
# delet extra columns:
    target_col = [c for c in df.columns if c not in ['Country Name', 'Country Code', 'Year']][0]
    return df[target_col].isnull().sum() / len(df) * 100

nan_incident  = get_nan_pct(df_incident_finally)
nan_gdp       = get_nan_pct(df_gdp_finally)
nan_bmi       = get_nan_pct(df_bmi_finally)
nan_age65     = get_nan_pct(df_pop65_finally)
nan_urban     = get_nan_pct(df_urban_finally)
nan_life      = get_nan_pct(df_life_expect_finally)
nan_fertility = get_nan_pct(df_fert_finally)
nan_labor     = get_nan_pct(df_labor_final)

# %% [markdown]
# Law NAN Percentages variables:

# %%
Table_Strong_Variables = [
    ['Incidence Rate (Y)', f"{nan_incident:.2f}%", 'Strong'],
    ['GDP per capita', f"{nan_gdp:.2f}%", 'Strong'],
    ['BMI Female', f"{nan_bmi:.2f}%", 'Strong'],
    ['Population 65+', f"{nan_age65:.2f}%", 'Strong'],
    ['Urban Population', f"{nan_urban:.2f}%", 'Strong'],
    ['Life Expectancy', f"{nan_life:.2f}%", 'Strong'],
    ['Fertility Rate', f"{nan_fertility:.2f}%", 'Strong'],
    ['Female Labor Rate', f"{nan_labor:.2f}%", 'Strong']
]
df_Table_Strong_Variables = pd.DataFrame(Table_Strong_Variables, columns=['Variable', 'Missing %', 'Status'])

# %% [markdown]
# High NAN Percentages variables:

# %%
Table_Weak_Variable = [
    ['Internet Users', f"{missing_percentage:.2f}%", 'Sensitivity Check'],
    ['Gov Health Spending', f"{missing_percentage_gov:.2f}%", 'Dropped (> 40% NaN)'],
    ['Current Health Expenditure', '40.71%', 'Dropped'],
    ['Broadband Subscriptions', '44.61%', 'Dropped'],
    ['Smoking prevalence', '81.68%', 'Dropped']
]
df_Table_Weak_Variable = pd.DataFrame(Table_Weak_Variable, columns=['Variable', 'Missing %', 'Status'])

# %% [markdown]
# # total report

# %%
# Print Tables Report
print("--- TABLE 1: FINAL MODEL VARIABLES ---")
print(df_Table_Strong_Variables)
print("\n--- TABLE 2: EXCLUDED VARIABLES ---")
print(df_Table_Weak_Variable)
# Out:
# --- TABLE 1: FINAL MODEL VARIABLES ---
#              Variable Missing %  Status
# 0  Incidence Rate (Y)     0.00%  Strong
# 1      GDP per capita     0.00%  Strong
# 2          BMI Female     0.00%  Strong
# 3      Population 65+     0.00%  Strong
# 4    Urban Population     0.00%  Strong
# 5     Life Expectancy     0.00%  Strong
# 6      Fertility Rate     0.00%  Strong
# 7   Female Labor Rate     0.00%  Strong
#
# --- TABLE 2: EXCLUDED VARIABLES ---
#                      Variable Missing %               Status
# 0              Internet Users     0.00%    Sensitivity Check
# 1         Gov Health Spending    47.30%  Dropped (> 40% NaN)
# 2  Current Health Expenditure    40.71%              Dropped
# 3     Broadband Subscriptions    44.61%              Dropped
# 4          Smoking prevalence    81.68%              Dropped

# %% [markdown]
# # Creat final list for merging in one data frame

# %%
final_list = [
    df_incident_finally, df_gdp_finally, df_bmi_finally, 
    df_pop65_finally , df_urban_finally, 
    df_life_expect_finally, df_fert_finally, df_labor_final]

# %%
clean_final_list= []
for i, df in enumerate(final_list):
    #create a copy for not changing the original dataframes
    temp_df = df.copy()
    #standarize column names 
    new_columns= {}
    for col in temp_df.columns:
        c_low = col.lower().strip()
        if 'country' in c_low and 'code' not in c_low:
            new_columns[col] = 'Country Name'
        elif 'code' in c_low:
            new_columns[col] = 'Country Code'
        elif 'year' in c_low:
            new_columns[col] = 'Year'
    
    temp_df = temp_df.rename(columns=new_columns)
    clean_final_list.append(temp_df)

# %%
raw_dataframes = [
    df_incident_finally,      
    df_gdp_finally,        
    df_bmi_finally,        
    df_pop65_finally, 
    df_urban_finally,         
    df_life_expect_finally, 
    df_fert_finally,    
    df_labor_final         
]
# all final column names
final_column_names= ['incidence', 'gdp', 'bmi', 'pop_65','urban_pop', 'life_exp', 'fertility', 'labor_rate']

# Cleanup & Merge
clean_dfs = []
for i, df_raw in enumerate(raw_dataframes):
    d = df_raw.copy()
    d = d.loc[:, ~d.columns.duplicated()] 
    d = d.iloc[:, [0, 1, 2]] 
    d.columns = ['country', 'year', final_column_names[i]]
    
    # standardizing country name and year format
    d['country'] = d['country'].astype(str).str.strip().str.lower()
    d['year'] = d['year'].astype(str).str.replace('.0', '', regex=False).str.strip()
    
    clean_dfs.append(d.drop_duplicates(subset=['country', 'year']))

# merging all dataframes
df_final = clean_dfs[0]
for next_df in clean_dfs[1:]:
    df_final = pd.merge(df_final, next_df, on=['country', 'year'], how='left')

#  be sure all final colums are numeric
for col in final_column_names:
    df_final[col] = pd.to_numeric(df_final[col], errors='coerce')

print(df_final.head(5))
# Out:
#        country  year  incidence           gdp       bmi    pop_65  urban_pop  \
# 0         chad  1990  11.784239   1705.042265  0.038681  3.455495     20.811
# 1        india  1990   8.650421   2203.147039  0.014403  4.037870     25.547
# 2  puerto rico  1990  51.408888           NaN  0.044402       NaN        NaN
# 3         oman  1990   5.197615  35201.552487  0.052449  2.453040     66.102
# 4       zambia  1990  14.798816   2425.111287  0.110025  2.880287     39.407
#
#    life_exp  fertility  labor_rate
# 0    48.799      7.219      64.570
# 1    59.358      4.045      30.225
# 2       NaN        NaN         NaN
# 3    71.752      6.456      22.489
# 4    49.410      6.567      51.414

# %%
from functools import reduce
import pandas as pd

# ۱. نام ستون‌های نهایی
final_column_names = ['incidence', 'gdp', 'bmi', 'pop_65', 'urban_pop', 'life_exp', 'fertility', 'labor_rate']

clean_dfs = []
for i, df_raw in enumerate(raw_dataframes):
    d = df_raw.copy()
    d = d.iloc[:, [0, 1, 2]] 
    d.columns = ['country', 'year', final_column_names[i]]
    d['country'] = d['country'].astype(str).str.strip().str.lower()
    d['year'] = pd.to_numeric(d['year'].astype(str).str[:4], errors='coerce')
    d[final_column_names[i]] = pd.to_numeric(d[final_column_names[i]], errors='coerce')
    clean_dfs.append(d.drop_duplicates(subset=['country', 'year']))

# ۳. ادغام تمام جداول با تابع reduce
df_final = reduce(lambda left, right: pd.merge(left, right, on=['country', 'year'], how='left'), clean_dfs)

# ۴. حذف ردیف‌هایی که مقدار هدف (Incidence) را ندارند
df_final = df_final.dropna(subset=['country', 'year', 'incidence'])

# ۵. نمایش خروجی
print(f"تعداد کل ردیف‌ها بعد از ادغام: {len(df_final)}")
print(df_final.head(3))
# Out:
# تعداد کل ردیف‌ها بعد از ادغام: 6936
#        country  year  incidence          gdp       bmi    pop_65  urban_pop  \
# 0         chad  1990  11.784239  1705.042265  0.038681  3.455495     20.811
# 1        india  1990   8.650421  2203.147039  0.014403  4.037870     25.547
# 2  puerto rico  1990  51.408888          NaN  0.044402       NaN        NaN
#
#    life_exp  fertility  labor_rate
# 0    48.799      7.219      64.570
# 1    59.358      4.045      30.225
# 2       NaN        NaN         NaN

# %% [markdown]
# # Heatmap:

# %%
# Choose numeric columns.
numeric_df = df_final.select_dtypes(include=['float64', 'int64'])
if 'year' in numeric_df.columns:
    numeric_df = numeric_df.drop(columns=['year'])

# Heatmap 
plt.figure(figsize=(14, 10))
corr_matrix = numeric_df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", center=0)
plt.title('Correlation Matrix of Breast Cancer Risk Factors')
plt.show()

# %%
df_final.to_csv(os.path.join(base_dir,"prepared_data_for_regression.csv"), index=False)
print("csv file created.")
# Out:
# csv file created.
